# %%
import pandas as pd
import pickle
import numpy as np

# %%
with open('reacdata.pc','rb') as f:
    data = pickle.load(f)

x1 = np.array(data['pH'])
x2 = np.array(data['ratio S/A'])
y = np.array(data['yield'])

X = np.array([x1,x2]).T

names = ['pH', 'rS']

# %%
df = pd.DataFrame(X, columns=names)
df.describe()
# Out:
#                pH          rS
# count  200.000000  200.000000
# mean    11.068315    2.078575
# std      0.569427    1.162030
# min     10.007862    0.037974
# 25%     10.595356    1.166206
# 50%     11.133683    2.032414
# 75%     11.539582    3.171647
# max     11.982803    3.998616

# %%
#Plot a scater_matrix of the features in X with scatter_matrix in pandas.plotting
from pandas.plotting import scatter_matrix

scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='pH', ylabel='pH'>,
#         <Axes: xlabel='rS', ylabel='pH'>],
#        [<Axes: xlabel='pH', ylabel='rS'>,
#         <Axes: xlabel='rS', ylabel='rS'>]], dtype=object)
