# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.integrate import solve_ivp 
from scipy.optimize import curve_fit
from FVMtools import FVMdisc2nd, FVMdiscBV, FVMdisc1st, FVMjpattern
import time

# %%
df = pd.read_excel('Project2B_appendix.xlsx', sheet_name='grad')

#Select column called V1

V1, Cs1, UV1 = df['V1'].to_numpy(), df['Cs1'].to_numpy(), df['UV1'].to_numpy()
V2, Cs2, UV2 = df['V2'].to_numpy(), df['Cs2'].to_numpy(), df['UV2'].to_numpy()
V3, Cs3, UV3 = df['V3'].to_numpy(), df['Cs3'].to_numpy(), df['UV3'].to_numpy()
V4, Cs4, UV4 = df['V4'].to_numpy(), df['Cs4'].to_numpy(), df['UV4'].to_numpy()
V5, Cs5, UV5 = df['V5'].to_numpy(), df['Cs5'].to_numpy(), df['UV5'].to_numpy()
V6, Cs6, UV6 = df['V6'].to_numpy(), df['Cs6'].to_numpy(), df['UV6'].to_numpy()

# %%
fig, ax = plt.subplots()

for i in range(1,7):
    ax.plot(df['V{}'.format(i)], df['Cs{}'.format(i)], label='Cs{}'.format(i))
    #ax.plot(df['V{}'.format(i)], df['UV{}'.format(i)], label='UV{}'.format(i))
ax.set_xlabel('V1')
ax.set_ylabel('Cs1')
ax.set_title('Data')
ax.legend()

plt.show()

# %%
beta = [8.41, 8.41, 4.57]
betaA = beta[0]
betaBC = beta[1]
betaD = beta[2]

qmax = 200 # for A, B and C

F = 5 #CV/h

# %%
M = 58.44
TotPep = 5/1
cAin = 0.169*TotPep
cBCin = 0.662*TotPep
cDin = 0.169*TotPep

SF = 0.10
SA = 0.05
SB = 0.35

ec = 0.42 
ep = 0.62 
L = 10e-2 #m

v = L #m/CV

Pe = 0.5 
Dp = 90e-6

# relations 
ee = ec + (1-ec)*ep 

Dax = (v*Dp)/Pe

N = 30

h = L/N


# discr 
[A2,A2f] = FVMdisc2nd(N, h, '3pc') 
[A1,A1f] = FVMdisc1st(N, h, '2pb') 
[B1,B0] = FVMdiscBV(N, h, [0, 1], [[1, -1],[0, 0]]) 

Ss = []
ts = []

# %%
def adsmodel(t, cq, H0A, H0BC, H0D, kin_A, kin_BC, kin_C): 
    N  =  int(len(cq)/6) 
    cA = cq[:N]
    cBC = cq[N:2*N]
    cD = cq[2*N:3*N]
    qA = cq[3*N:4*N]
    qBC = cq[4*N:5*N]
    qD = cq[5*N:6*N]
    
    if t<0:
        cinA = cAin
        cinBC = cBCin
        cinD = cDin
    else:
        cinA = 0
        cinBC = 0
        cinD = 0
    
    if t<0 : #Load
        S = SF 
    elif t<1: #Wash
        S = SA
    elif t<51 : #Elution
        Bstart = 0.1
        Bx = 0.01*(t-1) + Bstart
        S = Bx*SB+(1-Bx)*SA
    else: #Regeneration
        S = SB
        
    Ss.append(S)
    ts.append(t)
    HA = H0A*S**-betaA
    HBC = H0BC*S**-betaBC
    HD = H0D*S**-betaD
    
    qtot = qA+qBC+qD
    
    # adsorption 
    radsA = kin_A*(HA*cA*(1-(1/qmax)*qtot))-qA
    radsBC = kin_BC*(HBC*cBC*(1-(1/qmax)*qtot))-qBC
    radsD = kin_C*(HD*cD*(1-(1/qmax)*qtot))-qD
 
 
    # assembly 
    dcAdt = Dax*(A2@cA + A2f@(B1@cA + B0*cinA)) - v/ee*(A1@cA + A1f@(B1@cA + B0*cinA)) - (1-ec)/ec*radsA
    dcBCdt = Dax*(A2@cBC + A2f@(B1@cBC + B0*cinBC)) - v/ee*(A1@cBC + A1f@(B1@cBC + B0*cinBC)) - (1-ec)/ec*radsBC
    dcDdt = Dax*(A2@cD + A2f@(B1@cD + B0*cinD)) - v/ee*(A1@cD + A1f@(B1@cD + B0*cinD)) - (1-ec)/ec*radsD
   
    dcdt = np.hstack((dcAdt, dcBCdt, dcDdt))
    
    dqAdt = radsA
    dqBCdt = radsBC
    dqDdt = radsD
    
    dqdt = np.hstack((dqAdt, dqBCdt, dqDdt))
    
    dcqdt = np.hstack((dcdt, dqdt)) 
    return dcqdt 

def adssim(t, H0A, H0BC, H0D, kin_A, kin_BC, kin_C):
    tspan = [t[0],56]
    cqinit = np.hstack((0*np.ones(N),0*np.ones(N),0*np.ones(N), 0*np.ones(N), 0*np.ones(N), 0*np.ones(N) ))
    JP = FVMjpattern(lambda t, cq: adsmodel(t, cq, H0A, H0BC, H0D, kin_A, kin_BC, kin_C),len(cqinit))
    sol = solve_ivp(lambda t, cq: adsmodel(t, cq, H0A, H0BC, H0D, kin_A, kin_BC, kin_C), tspan, cqinit, method='BDF', t_eval=t,jac_sparsity=JP)
    t = sol.t
    cA = sol.y[N-1,:] 
    cBC = sol.y[2*N-1,:]
    cD = sol.y[3*N-1,:]
    
    return t, cA, cBC, cD

def fitting_func_H(t, H0A, H0BC, H0D, kin_A, kin_BC, kin_C):
    _, cA, cBC, cD = adssim(t, H0A, H0BC, H0D, kin_A, kin_BC, kin_C)
    CUV = cA + cBC + cD
    return CUV

def fitting_func_kin(t, kin_A, kin_BC, kin_C, H0A, H0BC, H0D):
    _, cA, cBC, cD = adssim(t, H0A, H0BC, H0D, kin_A, kin_BC, kin_C)
    CUV = cA + cBC + cD
    return CUV

# %%
H0 = [1.2e-5, 3.6e-6, 3.0e-4]


H0A = H0[0]
H0BC = H0[1]*0.8
H0D = H0[2]*0.3


kkin = np.array([15, 18, 43.4])/F
kkinA = kkin[0]*0.8
kkinBC = kkin[1]
kkinD = kkin[2]
fittingH = lambda t, H0A, H0BC, H0D: fitting_func_H(t, H0A, H0BC, H0D, kkinA, kkinBC, kkinD)
fittingKin = lambda t, kkinA, kkinBC, kkinD: fitting_func_kin(t, kkinA, kkinBC, kkinD, H0A, H0BC, H0D)

popt_H, pcov_H = curve_fit(fittingH, V1, UV1, p0=[H0A, H0BC, H0D], epsfcn=1e-4)
popt_kin, pcov_kin = curve_fit(fittingKin, V2, UV2, p0=[kkinA, kkinBC, kkinD], epsfcn=1e-4)
# Out:
# kin_A: 2.4000000000000004, kin_BC: 3.6, kin_C: 8.68
# kin_A: 2.4000000000000004, kin_BC: 3.6, kin_C: 8.68
# kin_A: 2.4000000000000004, kin_BC: 3.6, kin_C: 8.68
# kin_A: 2.4758946638440413, kin_BC: 3.6, kin_C: 8.68
# kin_A: 2.4000000000000004, kin_BC: 3.7138419957660616, kin_C: 8.68
# kin_A: 2.4000000000000004, kin_BC: 3.6, kin_C: 8.954485700902614
# kin_A: 2.684160191394912, kin_BC: 3.056222642579193, kin_C: 10.003003509843833
# kin_A: 2.769040789490526, kin_BC: 3.056222642579193, kin_C: 10.003003509843833
# kin_A: 2.684160191394912, kin_BC: 3.1528688884504823, kin_C: 10.003003509843833
# kin_A: 2.684160191394912, kin_BC: 3.056222642579193, kin_C: 10.319326255181483
# kin_A: 0.7505119073023977, kin_BC: 0.6971793968007071, kin_C: 2.075271832603592
# kin_A: 0.7510454926873255, kin_BC: 0.6972403483509563, kin_C: 2.0753118058517455
# kin_A: 0.7512494070175004, kin_BC: 0.6972631071603607, kin_C: 2.0753268179659887
# kin_A: 0.7513328214416947, kin_BC: 0.6972723292767529, kin_C: 2.07533291623061
# kin_A: 0.7750920514076581, kin_BC: 0.6972723292767529, kin_C: 2.07533291623061
# kin_A: 0.7513328214416947, kin_BC: 0.7193220163760073, kin_C: 2.07533291623061
# kin_A: 0.7513328214416947, kin_BC: 0.6972723292767529, kin_C: 2.1409607054146917
# kin_A: 0.7513014048632681, kin_BC: 0.697271379168238, kin_C: 2.0752929466848524
# kin_A: 0.7513213287191808, kin_BC: 0.6972719831019757, kin_C: 2.075318297198417
# kin_A: 0.7513316712143345, kin_BC: 0.6972722947028296, kin_C: 2.0753314532432277
# kin_A: 0.7513327064093981, kin_BC: 0.6972723258197973, kin_C: 2.075332769921021
# kin_A: 0.7750919327377209, kin_BC: 0.6972723258197973, kin_C: 2.075332769921021
# kin_A: 0.7513327064093981, kin_BC: 0.7193220128097332, kin_C: 2.075332769921021
# kin_A: 0.7513327064093981, kin_BC: 0.6972723258197973, kin_C: 2.1409605544783874
# kin_A: 0.7513324761581457, kin_BC: 0.6972723188750725, kin_C: 2.075332474132034
# kin_A: 0.7750916952052846, kin_BC: 0.6972723188750725, kin_C: 2.075332474132034
# kin_A: 0.7513324761581457, kin_BC: 0.719322005645397, kin_C: 2.075332474132034
# kin_A: 0.7513324761581457, kin_BC: 0.6972723188750725, kin_C: 2.140960249335731
# kin_A: 0.7513319770178648, kin_BC: 0.697272303902427, kin_C: 2.075332436477706
# kin_A: 0.7513324262423107, kin_BC: 0.6972723173778902, kin_C: 2.0753324703665204

# %%
print(f"Optimized H values: {popt_H}")
print(f"Optimized kin values: {popt_kin}")

print(f"kkina: {kkinA}, kkinc: {kkinBC}, kkind: {kkinD}")
print(f"H0A: {H0A}, H0BC: {H0BC}, H0D: {H0D}")
# Out:
# Optimized H values: [1.25034948e-05 2.52947096e-06 8.12872329e-05]
# Optimized kin values: [0.75133248 0.69727232 2.07533247]
# kkina: 2.4000000000000004, kkinc: 3.6, kkind: 8.68
# H0A: 1.2e-05, H0BC: 2.88e-06, H0D: 8.999999999999999e-05

# %%
t, cA_opt_H, cBC_opt_H, cD_opt_H = adssim(V1, *popt_H, kkinA, kkinBC, kkinD)
t, cA_opt_kin, cBC_opt_kin, cD_opt_kin = adssim(V1, H0A, H0BC, H0D, *popt_kin)
t, cA, cBC, cD = adssim(V1, H0A, H0BC, H0D, kkinA, kkinBC, kkinD)
t, cA_opt, cBC_opt, cD_opt = adssim(V1, *popt_H, *popt_kin)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(t, cA_opt_H+cBC_opt_H+cD_opt_H, label='cUV_opt_H', color='red')
ax.plot(t, cA_opt_kin+cBC_opt_kin+cD_opt_kin, label='cUV_opt_kin', color='blue')
ax.plot(t, cA+cBC+cD, label='cUV', color='green')
ax.plot(t, cA_opt+cBC_opt+cD_opt, label='cUV_opt', color='black')
ax.plot(V1, UV1, label='UV1', color='orange')
ax.legend()

#Green = Blue
#Black = Red

#Save figure
#plt.savefig(f'plots/PegKinD{skruv}.png', dpi=300)
